# %%
# !pip install keras-tcn
# !pip install -U finance-datareader
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras-tcn in /home/work/.local/lib/python3.8/site-packages (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from keras-tcn) (1.21.1)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.8/dist-packages (from keras-tcn) (0.16.1)
# Requirement already satisfied: tensorflow in /home/work/.local/lib/python3.8/site-packages (from keras-tcn) (2.11.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow->keras-tcn) (4.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/work/.local/lib/python3.8/site-packages (from tensorflow->keras-tcn) (0.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/work/.local/lib/python3.8/site-packages (from tensorflow->keras-tcn) (22.12.6)
# Requirement already satisfied: astunparse>=1.6.0 in /home/work/.local/lib/python3.8/site-packages (from tensorflow->keras-tcn) (1.6.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow->keras-tcn) (21.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->keras-tcn) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/work/.local/lib/python3.8/site-packages (from tensorflow->keras-tcn) (0.29.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/work/.local/lib/python3.8/site-packages (from tensorflow->keras-tcn) (3.19.6)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->keras-tcn) (1.12.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->keras-tcn) (3.6.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /home/work/.local/lib/python3.8/site-packages (from tensorflow->keras-tcn) (2.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->keras-tcn) (1.1.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /home/work/.local/lib/python3.8/site-packages (from tensorflow->keras-tcn) (2.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/work/.local/lib/python3.8/site-packages (from tensorflow->keras-tcn) (1.3.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /home/work/.local/lib/python3.8/site-packages (from tensorflow->keras-tcn) (2.11.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow->keras-tcn) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow->keras-tcn) (63.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow->keras-tcn) (1.39.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/work/.local/lib/python3.8/site-packages (from tensorflow->keras-tcn) (14.0.6)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow-addons->keras-tcn) (2.13.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow->keras-tcn) (0.36.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (2.27.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (3.3.7)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (2.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow->keras-tcn) (3.0.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (4.12.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (3.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow->keras-tcn) (3.2.0)
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: finance-datareader in /home/work/.local/lib/python3.8/site-packages (0.9.50)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from finance-datareader) (2.27.1)
# Requirement already satisfied: requests-file in /home/work/.local/lib/python3.8/site-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from finance-datareader) (4.64.0)
# Requirement already satisfied: pandas>=0.19.2 in /home/work/.local/lib/python3.8/site-packages (from finance-datareader) (1.5.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from finance-datareader) (4.5.0)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19.2->finance-datareader) (1.21.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19.2->finance-datareader) (2022.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.3.0->finance-datareader) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.3.0->finance-datareader) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.8/dist-packages (from requests>=2.3.0->finance-datareader) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.3.0->finance-datareader) (2021.10.8)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from requests-file->finance-datareader) (1.15.0)
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import FinanceDataReader as fdr
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tcn import TCN
# Out:
# /home/work/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.0' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# 2023-01-27 01:57:32.805226: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-27 01:57:32.969465: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-01-27 01:57:35.311714: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/compat/lib:/usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/lib:/usr/local/cuda/lib64:/usr/local/nvidia/lib64:/usr/include/x86_64-linux-gnu
# 2023-01-27 01:57:35.311854: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/compat/lib:/usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/lib:/usr/local/cuda/lib64:/usr/local/nvidia/lib64:/usr/include/x86_64-linux-gnu
# 2023-01-27 01:57:35.311868: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
kospi_train = fdr.DataReader('KS11', '1990-01-01','2017-12-31')
kospi_train['Change1'] = kospi_train['Close']/kospi_train['Close'].shift(1) - 1
kospi_train['Change7'] = kospi_train['Close']/kospi_train['Close'].shift(7) - 1
kospi_train['Change15'] = kospi_train['Close']/kospi_train['Close'].shift(15) - 1
kospi_train['Change30'] = kospi_train['Close']/kospi_train['Close'].shift(30) - 1
print(kospi_train.head())
print(kospi_train.columns)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1996-12-11  705.989990  709.479980  704.429993  704.679993  704.679993
# 1996-12-12  705.109985  706.010010  688.739990  689.380005  689.380005
# 1996-12-13  690.440002  695.719971  677.640015  689.070007  689.070007
# 1996-12-16  686.969971  686.969971  667.710022  673.919983  673.919983
# 1996-12-17  675.349976  680.090027  660.390015  663.349976  663.349976
#
#              Volume   Change1  Change7  Change15  Change30
# Date
# 1996-12-11  28000.0       NaN      NaN       NaN       NaN
# 1996-12-12  25900.0 -0.021712      NaN       NaN       NaN
# 1996-12-13  26500.0 -0.000450      NaN       NaN       NaN
# 1996-12-16  22800.0 -0.021986      NaN       NaN       NaN
# 1996-12-17  31600.0 -0.015684      NaN       NaN       NaN
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Change1',
#        'Change7', 'Change15', 'Change30'],
#       dtype='object')

# %%
kospi_train = kospi_train.dropna()
print(kospi_train.head())
print(kospi_train.columns)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1997-01-24  669.030029  679.559998  658.179993  679.559998  679.559998
# 1997-01-27  684.309998  685.460022  664.679993  664.700012  664.700012
# 1997-01-28  661.659973  677.630005  653.419983  662.849976  662.849976
# 1997-01-29  663.330017  672.900024  654.950012  663.559998  663.559998
# 1997-01-30  663.650024  679.039978  662.270020  676.520020  676.520020
#
#              Volume   Change1   Change7  Change15  Change30
# Date
# 1997-01-24  35500.0  0.003915 -0.028867  0.039416 -0.013801
# 1997-01-27  28300.0 -0.021867 -0.066249  0.060347 -0.013681
# 1997-01-28  30400.0 -0.002783 -0.054665  0.084772 -0.000754
# 1997-01-29  30200.0  0.001071 -0.076413  0.067830  0.003281
# 1997-01-30  28800.0  0.019531 -0.020303  0.057277 -0.020913
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Change1',
#        'Change7', 'Change15', 'Change30'],
#       dtype='object')

# %%
kospi_train_close = kospi_train['Close']
kospi_train_c1 = kospi_train['Change1']
kospi_train_c7 = kospi_train['Change7']
kospi_train_c15 = kospi_train['Change15']
kospi_train_c30 = kospi_train['Change30']
print(kospi_train_close, kospi_train_c1)
# Out:
# Date
# 1997-01-24     679.559998
# 1997-01-27     664.700012
# 1997-01-28     662.849976
# 1997-01-29     663.559998
# 1997-01-30     676.520020
#                  ...
# 2017-12-21    2429.830078
# 2017-12-22    2440.540039
# 2017-12-26    2427.340088
# 2017-12-27    2436.669922
# 2017-12-28    2467.489990
# Name: Close, Length: 4668, dtype: float64 Date
# 1997-01-24    0.003915
# 1997-01-27   -0.021867
# 1997-01-28   -0.002783
# 1997-01-29    0.001071
# 1997-01-30    0.019531
#                 ...
# 2017-12-21   -0.019649
# 2017-12-22    0.004408
# 2017-12-26   -0.005409
# 2017-12-27    0.003844
# 2017-12-28    0.012648
# Name: Change1, Length: 4668, dtype: float64

# %%
kospi_test = fdr.DataReader('KS11', '2018-01-01')
kospi_test['Change1'] = kospi_test['Close']/kospi_test['Close'].shift(1) - 1
kospi_test['Change7'] = kospi_test['Close']/kospi_test['Close'].shift(7) - 1
kospi_test['Change15'] = kospi_test['Close']/kospi_test['Close'].shift(15) - 1
kospi_test['Change30'] = kospi_test['Close']/kospi_test['Close'].shift(30) - 1
print(kospi_test.head())
print(kospi_test.columns)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-01-02  2474.860107  2481.020020  2465.939941  2479.649902  2479.649902
# 2018-01-03  2484.629883  2493.399902  2481.909912  2486.350098  2486.350098
# 2018-01-04  2502.500000  2502.500000  2466.449951  2466.459961  2466.459961
# 2018-01-05  2476.850098  2497.520020  2475.510010  2497.520020  2497.520020
# 2018-01-08  2510.699951  2515.370117  2494.179932  2513.280029  2513.280029
#
#             Volume   Change1  Change7  Change15  Change30
# Date
# 2018-01-02  262200       NaN      NaN       NaN       NaN
# 2018-01-03  331100  0.002702      NaN       NaN       NaN
# 2018-01-04  333800 -0.008000      NaN       NaN       NaN
# 2018-01-05  308800  0.012593      NaN       NaN       NaN
# 2018-01-08  311400  0.006310      NaN       NaN       NaN
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Change1',
#        'Change7', 'Change15', 'Change30'],
#       dtype='object')

# %%
kospi_test = kospi_test.dropna()
print(kospi_test.head())
print(kospi_test.columns)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-02-13  2402.889893  2421.800049  2388.540039  2395.189941  2395.189941
# 2018-02-14  2412.469971  2426.629883  2408.020020  2421.830078  2421.830078
# 2018-02-19  2452.520020  2455.120117  2428.149902  2442.820068  2442.820068
# 2018-02-20  2433.350098  2438.479980  2411.229980  2415.120117  2415.120117
# 2018-02-21  2417.729980  2432.449951  2404.020020  2429.649902  2429.649902
#
#             Volume   Change1   Change7  Change15  Change30
# Date
# 2018-02-13  423400  0.004113 -0.051556 -0.055748 -0.034061
# 2018-02-14  305700  0.011122 -0.028061 -0.045772 -0.025950
# 2018-02-19  322100  0.008667 -0.004276 -0.046604 -0.009585
# 2018-02-20  421500 -0.011339  0.007744 -0.062002 -0.032993
# 2018-02-21  432300  0.006016  0.009150 -0.064868 -0.033275
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Change1',
#        'Change7', 'Change15', 'Change30'],
#       dtype='object')

# %%
kospi_test_close = kospi_test['Close']
kospi_test_c1 = kospi_test['Change1']
kospi_test_c7 = kospi_test['Change7']
kospi_test_c15 = kospi_test['Change15']
kospi_test_c30 = kospi_test['Change30']
print(kospi_test_close, kospi_test_c1)
# Out:
# Date
# 2018-02-13    2395.189941
# 2018-02-14    2421.830078
# 2018-02-19    2442.820068
# 2018-02-20    2415.120117
# 2018-02-21    2429.649902
#                  ...
# 2023-01-19    2380.340088
# 2023-01-20    2395.260010
# 2023-01-25    2428.570068
# 2023-01-26    2468.649902
# 2023-01-27    2483.199951
# Name: Close, Length: 1218, dtype: float64 Date
# 2018-02-13    0.004113
# 2018-02-14    0.011122
# 2018-02-19    0.008667
# 2018-02-20   -0.011339
# 2018-02-21    0.006016
#                 ...
# 2023-01-19    0.005075
# 2023-01-20    0.006268
# 2023-01-25    0.013907
# 2023-01-26    0.016503
# 2023-01-27    0.005894
# Name: Change1, Length: 1218, dtype: float64

# %%
kospi_train_close = kospi_train_close.values
kospi_train_c1 = 100 * kospi_train_c1.values
kospi_train_c7 = 100 * kospi_train_c7.values
kospi_train_c15 = 100 * kospi_train_c15.values
kospi_train_c30 = 100 * kospi_train_c30.values

kospi_test_close = kospi_test_close.values
kospi_test_c1 = 100 * kospi_test_c1.values
kospi_test_c7 = 100 * kospi_test_c7.values
kospi_test_c15 = 100 * kospi_test_c15.values
kospi_test_c30 = 100 * kospi_test_c30.values
print(kospi_test_c1)
# Out:
# [0.41125768 1.11223484 0.86669953 ... 1.39066564 1.65034703 0.58939297]

# %%
lookback_window = 60
x_train_1, y_train_1 = [], []
x_train_7, y_train_7 = [], []
x_train_15, y_train_15 = [], []
x_train_30, y_train_30 = [], []

# %%
for i in range(lookback_window, len(kospi_train_close)-1):
    x_train_1.append(kospi_train_close[i - lookback_window:i])
    y_train_1.append(kospi_train_c1[i])

for i in range(lookback_window, len(kospi_train_close)-6):
    x_train_7.append(kospi_train_close[i - lookback_window:i])
    y_train_7.append(kospi_train_c7[i+6])

for i in range(lookback_window, len(kospi_train_close)-14):
    x_train_15.append(kospi_train_close[i - lookback_window:i])
    y_train_15.append(kospi_train_c15[i+14])

for i in range(lookback_window, len(kospi_train_close)-29):
    x_train_30.append(kospi_train_close[i - lookback_window:i])
    y_train_30.append(kospi_train_c30[i+29])

# %%
for index in range(len(y_train_1)):
    if y_train_1[index]>= -0.01 and y_train_1[index] < 0.01:
        y_train_1[index] = 'neutral'
    elif y_train_1[index] >= 0.01:
        y_train_1[index] = 'increase'
    else:
        y_train_1[index] = 'decrease'
        
for index in range(len(y_train_7)):
    if y_train_7[index]>= -0.01 and y_train_7[index] < 0.01:
        y_train_7[index] = 'neutral'
    elif y_train_7[index] >= 0.01:
        y_train_7[index] = 'increase'
    else:
        y_train_7[index] = 'decrease'

for index in range(len(y_train_15)):
    if y_train_15[index]>= -0.01 and y_train_15[index] < 0.01:
        y_train_15[index] = 'neutral'
    elif y_train_15[index] >= 0.01:
        y_train_15[index] = 'increase'
    else:
        y_train_15[index] = 'decrease'

for index in range(len(y_train_30)):
    if y_train_30[index]>= -0.01 and y_train_30[index] < 0.01:
        y_train_30[index] = 'neutral'
    elif y_train_30[index] >= 0.01:
        y_train_30[index] = 'increase'
    else:
        y_train_30[index] = 'decrease'

# %%
x_train_1 = np.array(x_train_1)
y_train_1 = np.array(y_train_1)
x_train_1 = x_train_1.reshape((4607, -1, 1))
#y_train_1 = y_train_1.reshape((-1, 1))

x_train_7 = np.array(x_train_7)
y_train_7 = np.array(y_train_7)
x_train_7 = x_train_7.reshape((4602, -1, 1))
#y_train_7 = y_train_7.reshape((-1, 1))

x_train_15 = np.array(x_train_15)
y_train_15 = np.array(y_train_15)
x_train_15 = x_train_15.reshape((4594, -1, 1))
#y_train_15 = y_train_15.reshape((-1, 1))

x_train_30 = np.array(x_train_30)
y_train_30 = np.array(y_train_30)
x_train_30 = x_train_30.reshape((4579, -1, 1))
#y_train_30 = y_train_30.reshape((-1, 1))

print(x_train_1.shape, x_train_7.shape, x_train_15.shape, x_train_30.shape)
print(y_train_1.shape, y_train_7.shape, y_train_15.shape, y_train_30.shape)
# Out:
# (4607, 60, 1) (4602, 60, 1) (4594, 60, 1) (4579, 60, 1)
# (4607,) (4602,) (4594,) (4579,)

# %%
x_test_1, y_test_1 = [], []
x_test_7, y_test_7 = [], []
x_test_15, y_test_15 = [], []
x_test_30, y_test_30 = [], []

# %%
for i in range(lookback_window, len(kospi_test_close)-1):
    x_test_1.append(kospi_test_close[i - lookback_window:i])
    y_test_1.append(kospi_test_c1[i])

for i in range(lookback_window, len(kospi_test_close)-6):
    x_test_7.append(kospi_test_close[i - lookback_window:i])
    y_test_7.append(kospi_test_c7[i+6])

for i in range(lookback_window, len(kospi_test_close)-14):
    x_test_15.append(kospi_test_close[i - lookback_window:i])
    y_test_15.append(kospi_test_c15[i+14])

for i in range(lookback_window, len(kospi_test_close)-29):
    x_test_30.append(kospi_test_close[i - lookback_window:i])
    y_test_30.append(kospi_test_c30[i+29])

# %%
for index in range(len(y_test_1)):
    if y_test_1[index]>= -0.01 and y_test_1[index] < 0.01:
        y_test_1[index] = 'neutral'
    elif y_test_1[index] >= 0.01:
        y_test_1[index] = 'increase'
    else:
        y_test_1[index] = 'decrease'
        
for index in range(len(y_test_7)):
    if y_test_7[index]>= -0.01 and y_test_7[index] < 0.01:
        y_test_7[index] = 'neutral'
    elif y_test_7[index] >= 0.01:
        y_test_7[index] = 'increase'
    else:
        y_test_7[index] = 'decrease'

for index in range(len(y_test_15)):
    if y_test_15[index]>= -0.01 and y_test_15[index] < 0.01:
        y_test_15[index] = 'neutral'
    elif y_test_15[index] >= 0.01:
        y_test_15[index] = 'increase'
    else:
        y_test_15[index] = 'decrease'

for index in range(len(y_test_30)):
    if y_test_30[index]>= -0.01 and y_test_30[index] < 0.01:
        y_test_30[index] = 'neutral'
    elif y_test_30[index] >= 0.01:
        y_test_30[index] = 'increase'
    else:
        y_test_30[index] = 'decrease'

# %%
x_test_1 = np.array(x_test_1)
y_test_1 = np.array(y_test_1)
x_test_1 = x_test_1.reshape((1157, -1, 1))
#y_test_1 = y_test_1.reshape((-1, 1))

x_test_7 = np.array(x_test_7)
y_test_7 = np.array(y_test_7)
x_test_7 = x_test_7.reshape((1152, -1, 1))
#y_test_7 = y_test_7.reshape((-1, 1))

x_test_15 = np.array(x_test_15)
y_test_15 = np.array(y_test_15)
x_test_15 = x_test_15.reshape((1144, -1, 1))
#y_test_15 = y_test_15.reshape((-1, 1))

x_test_30 = np.array(x_test_30)
y_test_30 = np.array(y_test_30)
x_test_30 = x_test_30.reshape((1129, -1, 1))
#y_test_30 = y_test_30.reshape((-1, 1))

# %%
print(x_test_1.shape, x_test_7.shape, x_test_15.shape, x_test_30.shape)
print(y_test_1.shape, y_test_7.shape, y_test_15.shape, y_test_30.shape)
# Out:
# (1157, 60, 1) (1152, 60, 1) (1144, 60, 1) (1129, 60, 1)
# (1157,) (1152,) (1144,) (1129,)

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
encoder = LabelEncoder()
encoder.fit(y_train_1)

y_train_1_e = to_categorical(encoder.transform(y_train_1))
y_train_7_e = to_categorical(encoder.transform(y_train_7))
y_train_15_e = to_categorical(encoder.transform(y_train_15))
y_train_30_e = to_categorical(encoder.transform(y_train_30))

y_test_1_e = to_categorical(encoder.transform(y_test_1))
y_test_7_e = to_categorical(encoder.transform(y_test_7))
y_test_15_e = to_categorical(encoder.transform(y_test_15))
y_test_30_e = to_categorical(encoder.transform(y_test_30))

# %%
model_1 = Sequential([
    TCN(input_shape=(lookback_window, 1),
        kernel_size=2,
        use_skip_connections=False,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=False
        ),
    Dense(3, activation='softmax')
])

model_1.summary()
model_1.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
####
model_7 = Sequential([
    TCN(input_shape=(lookback_window, 1),
        kernel_size=2,
        use_skip_connections=False,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=False
        ),
    Dense(3, activation='softmax')
])

model_7.summary()
model_7.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
####
model_15 = Sequential([
    TCN(input_shape=(lookback_window, 1),
        kernel_size=2,
        use_skip_connections=False,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=False
        ),
    Dense(3, activation='softmax')
])

model_15.summary()
model_15.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
####
model_30 = Sequential([
    TCN(input_shape=(lookback_window, 1),
        kernel_size=2,
        use_skip_connections=False,
        use_batch_norm=False,
        use_weight_norm=False,
        use_layer_norm=False
        ),
    Dense(3, activation='softmax')
])

model_30.summary()
model_30.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# 2023-01-27 02:02:07.062244: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/compat/lib:/usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/lib:/usr/local/cuda/lib64:/usr/local/nvidia/lib64:/usr/include/x86_64-linux-gnu
# 2023-01-27 02:02:07.062290: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-01-27 02:02:07.062318: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist
# 2023-01-27 02:02:07.062761: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tcn (TCN)                   (None, 64)                91136
#
#  dense (Dense)               (None, 3)                 195
#
# =================================================================
# Total params: 91,331
# Trainable params: 91,331
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tcn_1 (TCN)                 (None, 64)                91136
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 91,331
# Trainable params: 91,331
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tcn_2 (TCN)                 (None, 64)                91136
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 91,331
# Trainable params: 91,331
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tcn_3 (TCN)                 (None, 64)                91136
#
#  dense_3 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 91,331
# Trainable params: 91,331
# Non-trainable params: 0
# _________________________________________________________________

# %%
print('Train model_1...')
model_1.fit(x_train_1, y_train_1_e, epochs=100, verbose=1)
p_test_1 = model_1.predict(x_test_1)

print('Train model_7...')
model_7.fit(x_train_7, y_train_7_e, epochs=100, verbose=1)
p_test_7 = model_7.predict(x_test_7)

print('Train model_15...')
model_15.fit(x_train_15, y_train_15_e, epochs=100, verbose=1)
p_test_15 = model_15.predict(x_test_15)

print('Train model_30...')
model_30.fit(x_train_30, y_train_30_e, epochs=100, verbose=1)
p_test_30 = model_30.predict(x_test_30)
# Out:
# Train model_1...
# Epoch 1/100
# 144/144 [==============================] - 5s 18ms/step - loss: 1658.4349 - accuracy: 0.4925
# Epoch 2/100
# 144/144 [==============================] - 3s 18ms/step - loss: 332.4568 - accuracy: 0.4845
# Epoch 3/100
# 144/144 [==============================] - 2s 17ms/step - loss: 249.7529 - accuracy: 0.4801
# Epoch 4/100
# 144/144 [==============================] - 2s 17ms/step - loss: 134.4137 - accuracy: 0.4903
# Epoch 5/100
# 144/144 [==============================] - 2s 17ms/step - loss: 124.4942 - accuracy: 0.4966
# Epoch 6/100
# 144/144 [==============================] - 2s 17ms/step - loss: 170.4035 - accuracy: 0.4949
# Epoch 7/100
# 144/144 [==============================] - 2s 17ms/step - loss: 171.9065 - accuracy: 0.4884
# Epoch 8/100
# 144/144 [==============================] - 2s 17ms/step - loss: 79.7803 - accuracy: 0.4867
# Epoch 9/100
# 144/144 [==============================] - 2s 17ms/step - loss: 70.0810 - accuracy: 0.4973
# Epoch 10/100
# 144/144 [==============================] - 2s 17ms/step - loss: 104.7175 - accuracy: 0.5003
# Epoch 11/100
# 144/144 [==============================] - 2s 17ms/step - loss: 97.9560 - accuracy: 0.4851
# Epoch 12/100
# 144/144 [==============================] - 2s 17ms/step - loss: 102.4394 - accuracy: 0.4890
# Epoch 13/100
# 144/144 [==============================] - 2s 17ms/step - loss: 113.3946 - accuracy: 0.4840
# Epoch 14/100
# 144/144 [==============================] - 2s 17ms/step - loss: 85.2515 - accuracy: 0.4971
# Epoch 15/100
# 144/144 [==============================] - 2s 17ms/step - loss: 76.7823 - accuracy: 0.4929
# Epoch 16/100
# 144/144 [==============================] - 2s 17ms/step - loss: 75.9165 - accuracy: 0.5075
# Epoch 17/100
# 144/144 [==============================] - 2s 17ms/step - loss: 60.6716 - accuracy: 0.4951
# Epoch 18/100
# 144/144 [==============================] - 2s 17ms/step - loss: 67.4608 - accuracy: 0.5001
# Epoch 19/100
# 144/144 [==============================] - 2s 17ms/step - loss: 61.9209 - accuracy: 0.4862
# Epoch 20/100
# 144/144 [==============================] - 2s 17ms/step - loss: 66.5655 - accuracy: 0.4975
# Epoch 21/100
# 144/144 [==============================] - 2s 17ms/step - loss: 58.8545 - accuracy: 0.4912
# Epoch 22/100
# 144/144 [==============================] - 2s 17ms/step - loss: 64.0867 - accuracy: 0.4843
# Epoch 23/100
# 144/144 [==============================] - 2s 17ms/step - loss: 43.6274 - accuracy: 0.5042
# Epoch 24/100
# 144/144 [==============================] - 2s 17ms/step - loss: 69.7239 - accuracy: 0.4799
# Epoch 25/100
# 144/144 [==============================] - 2s 17ms/step - loss: 62.2344 - accuracy: 0.4982
# Epoch 26/100
# 144/144 [==============================] - 2s 17ms/step - loss: 55.1208 - accuracy: 0.4793
# Epoch 27/100
# 144/144 [==============================] - 2s 17ms/step - loss: 52.1721 - accuracy: 0.4869
# Epoch 28/100
# 144/144 [==============================] - 2s 17ms/step - loss: 56.0802 - accuracy: 0.4888
# Epoch 29/100
# 144/144 [==============================] - 2s 17ms/step - loss: 39.8180 - accuracy: 0.5034
# Epoch 30/100
# 144/144 [==============================] - 2s 17ms/step - loss: 27.6086 - accuracy: 0.5018
# Epoch 31/100
# 144/144 [==============================] - 2s 17ms/step - loss: 54.7849 - accuracy: 0.5107
# Epoch 32/100
# 144/144 [==============================] - 2s 17ms/step - loss: 35.0837 - accuracy: 0.4880
# Epoch 33/100
# 144/144 [==============================] - 2s 17ms/step - loss: 32.0486 - accuracy: 0.4906
# Epoch 34/100
# 144/144 [==============================] - 2s 17ms/step - loss: 28.2726 - accuracy: 0.5036
# Epoch 35/100
# 144/144 [==============================] - 2s 17ms/step - loss: 34.5994 - accuracy: 0.5040
# Epoch 36/100
# 144/144 [==============================] - 2s 17ms/step - loss: 29.7443 - accuracy: 0.4910
# Epoch 37/100
# 144/144 [==============================] - 2s 17ms/step - loss: 45.9750 - accuracy: 0.4836
# Epoch 38/100
# 144/144 [==============================] - 2s 17ms/step - loss: 27.8265 - accuracy: 0.5029
# Epoch 39/100
# 144/144 [==============================] - 2s 17ms/step - loss: 24.5786 - accuracy: 0.5010
# Epoch 40/100
# 144/144 [==============================] - 2s 17ms/step - loss: 28.0499 - accuracy: 0.4847
# Epoch 41/100
# 144/144 [==============================] - 2s 17ms/step - loss: 40.0952 - accuracy: 0.4838
# Epoch 42/100
# 144/144 [==============================] - 2s 17ms/step - loss: 29.0190 - accuracy: 0.5047
# Epoch 43/100
# 144/144 [==============================] - 2s 17ms/step - loss: 25.2385 - accuracy: 0.5040
# Epoch 44/100
# 144/144 [==============================] - 2s 17ms/step - loss: 21.3899 - accuracy: 0.4982
# Epoch 45/100
# 144/144 [==============================] - 2s 17ms/step - loss: 16.9408 - accuracy: 0.4903
# Epoch 46/100
# 144/144 [==============================] - 2s 17ms/step - loss: 41.0698 - accuracy: 0.4934
# Epoch 47/100
# 144/144 [==============================] - 2s 17ms/step - loss: 32.3752 - accuracy: 0.4864
# Epoch 48/100
# 144/144 [==============================] - 2s 17ms/step - loss: 17.6458 - accuracy: 0.4877
# Epoch 49/100
# 144/144 [==============================] - 2s 17ms/step - loss: 19.9506 - accuracy: 0.4886
# Epoch 50/100
# 144/144 [==============================] - 2s 17ms/step - loss: 20.4129 - accuracy: 0.4969
# Epoch 51/100
# 144/144 [==============================] - 2s 17ms/step - loss: 19.6356 - accuracy: 0.4969
# Epoch 52/100
# 144/144 [==============================] - 2s 17ms/step - loss: 25.0656 - accuracy: 0.4916
# Epoch 53/100
# 144/144 [==============================] - 2s 17ms/step - loss: 18.7612 - accuracy: 0.4971
# Epoch 54/100
# 144/144 [==============================] - 2s 17ms/step - loss: 37.1893 - accuracy: 0.4869
# Epoch 55/100
# 144/144 [==============================] - 2s 17ms/step - loss: 23.6217 - accuracy: 0.5031
# Epoch 56/100
# 144/144 [==============================] - 2s 17ms/step - loss: 24.2188 - accuracy: 0.4847
# Epoch 57/100
# 144/144 [==============================] - 2s 17ms/step - loss: 24.4728 - accuracy: 0.4882
# Epoch 58/100
# 144/144 [==============================] - 2s 17ms/step - loss: 20.1016 - accuracy: 0.4901
# Epoch 59/100
# 144/144 [==============================] - 2s 17ms/step - loss: 19.7978 - accuracy: 0.4821
# Epoch 60/100
# 144/144 [==============================] - 2s 17ms/step - loss: 25.5497 - accuracy: 0.4960
# Epoch 61/100
# 144/144 [==============================] - 2s 17ms/step - loss: 20.9497 - accuracy: 0.4849
# Epoch 62/100
# 144/144 [==============================] - 2s 17ms/step - loss: 18.3642 - accuracy: 0.5018
# Epoch 63/100
# 144/144 [==============================] - 2s 17ms/step - loss: 19.1545 - accuracy: 0.4832
# Epoch 64/100
# 144/144 [==============================] - 2s 17ms/step - loss: 17.9471 - accuracy: 0.5055
# Epoch 65/100
# 144/144 [==============================] - 2s 17ms/step - loss: 15.4941 - accuracy: 0.4893
# Epoch 66/100
# 144/144 [==============================] - 2s 17ms/step - loss: 18.9993 - accuracy: 0.4929
# Epoch 67/100
# 144/144 [==============================] - 2s 17ms/step - loss: 15.1338 - accuracy: 0.4862
# Epoch 68/100
# 144/144 [==============================] - 2s 17ms/step - loss: 22.6257 - accuracy: 0.4875
# Epoch 69/100
# 144/144 [==============================] - 2s 17ms/step - loss: 18.1528 - accuracy: 0.4938
# Epoch 70/100
# 144/144 [==============================] - 2s 17ms/step - loss: 20.0391 - accuracy: 0.4864
# Epoch 71/100
# 144/144 [==============================] - 2s 17ms/step - loss: 23.1794 - accuracy: 0.4988
# Epoch 72/100
# 144/144 [==============================] - 2s 17ms/step - loss: 17.0205 - accuracy: 0.4884
# Epoch 73/100
# 144/144 [==============================] - 2s 17ms/step - loss: 18.1248 - accuracy: 0.4914
# Epoch 74/100
# 144/144 [==============================] - 2s 17ms/step - loss: 12.4854 - accuracy: 0.4893
# Epoch 75/100
# 144/144 [==============================] - 2s 17ms/step - loss: 15.8637 - accuracy: 0.4936
# Epoch 76/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.9330 - accuracy: 0.5008
# Epoch 77/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.6997 - accuracy: 0.4862
# Epoch 78/100
# 144/144 [==============================] - 2s 17ms/step - loss: 16.0962 - accuracy: 0.4888
# Epoch 79/100
# 144/144 [==============================] - 2s 17ms/step - loss: 19.2677 - accuracy: 0.4979
# Epoch 80/100
# 144/144 [==============================] - 2s 17ms/step - loss: 16.9228 - accuracy: 0.4873
# Epoch 81/100
# 144/144 [==============================] - 2s 17ms/step - loss: 14.0968 - accuracy: 0.4951
# Epoch 82/100
# 144/144 [==============================] - 2s 17ms/step - loss: 17.8363 - accuracy: 0.5014
# Epoch 83/100
# 144/144 [==============================] - 2s 17ms/step - loss: 12.1821 - accuracy: 0.4990
# Epoch 84/100
# 144/144 [==============================] - 2s 17ms/step - loss: 16.0372 - accuracy: 0.4719
# Epoch 85/100
# 144/144 [==============================] - 2s 17ms/step - loss: 18.9951 - accuracy: 0.4888
# Epoch 86/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.2859 - accuracy: 0.4882
# Epoch 87/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.5395 - accuracy: 0.4888
# Epoch 88/100
# 144/144 [==============================] - 2s 17ms/step - loss: 14.3663 - accuracy: 0.4975
# Epoch 89/100
# 144/144 [==============================] - 2s 17ms/step - loss: 14.4661 - accuracy: 0.4979
# Epoch 90/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.7288 - accuracy: 0.4888
# Epoch 91/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.1691 - accuracy: 0.4910
# Epoch 92/100
# 144/144 [==============================] - 2s 17ms/step - loss: 17.5375 - accuracy: 0.4899
# Epoch 93/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.0635 - accuracy: 0.4973
# Epoch 94/100
# 144/144 [==============================] - 2s 17ms/step - loss: 15.3035 - accuracy: 0.4825
# Epoch 95/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.0106 - accuracy: 0.4856
# Epoch 96/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.4365 - accuracy: 0.4856
# Epoch 97/100
# 144/144 [==============================] - 2s 17ms/step - loss: 11.5863 - accuracy: 0.4947
# Epoch 98/100
# 144/144 [==============================] - 2s 17ms/step - loss: 15.2064 - accuracy: 0.4778
# Epoch 99/100
# 144/144 [==============================] - 2s 17ms/step - loss: 14.2170 - accuracy: 0.4992
# Epoch 100/100
# 144/144 [==============================] - 2s 17ms/step - loss: 12.9628 - accuracy: 0.4966
# 37/37 [==============================] - 1s 21ms/step
# Train model_7...
# Epoch 1/100
# 144/144 [==============================] - 5s 18ms/step - loss: 1713.0575 - accuracy: 0.4989
# Epoch 2/100
# 144/144 [==============================] - 3s 17ms/step - loss: 356.7293 - accuracy: 0.5000
# Epoch 3/100
# 144/144 [==============================] - 2s 17ms/step - loss: 146.6058 - accuracy: 0.5165
# Epoch 4/100
# 144/144 [==============================] - 3s 18ms/step - loss: 119.6501 - accuracy: 0.5052
# Epoch 5/100
# 144/144 [==============================] - 2s 17ms/step - loss: 119.7215 - accuracy: 0.4870
# Epoch 6/100
# 144/144 [==============================] - 2s 17ms/step - loss: 104.6110 - accuracy: 0.5104
# Epoch 7/100
# 144/144 [==============================] - 2s 17ms/step - loss: 80.6805 - accuracy: 0.5100
# Epoch 8/100
# 144/144 [==============================] - 2s 17ms/step - loss: 112.4450 - accuracy: 0.5026
# Epoch 9/100
# 144/144 [==============================] - 2s 17ms/step - loss: 108.2015 - accuracy: 0.5100
# Epoch 10/100
# 144/144 [==============================] - 2s 17ms/step - loss: 62.9313 - accuracy: 0.5080
# Epoch 11/100
# 144/144 [==============================] - 2s 17ms/step - loss: 53.7271 - accuracy: 0.5174
# Epoch 12/100
# 144/144 [==============================] - 3s 18ms/step - loss: 53.3177 - accuracy: 0.4996
# Epoch 13/100
# 144/144 [==============================] - 3s 19ms/step - loss: 54.1340 - accuracy: 0.5041
# Epoch 14/100
# 144/144 [==============================] - 2s 17ms/step - loss: 47.5183 - accuracy: 0.5093
# Epoch 15/100
# 144/144 [==============================] - 2s 17ms/step - loss: 49.5164 - accuracy: 0.5128
# Epoch 16/100
# 144/144 [==============================] - 2s 17ms/step - loss: 125.7537 - accuracy: 0.4983
# Epoch 17/100
# 144/144 [==============================] - 2s 17ms/step - loss: 43.0275 - accuracy: 0.5104
# Epoch 18/100
# 144/144 [==============================] - 2s 17ms/step - loss: 58.6616 - accuracy: 0.4985
# Epoch 19/100
# 144/144 [==============================] - 2s 17ms/step - loss: 47.0565 - accuracy: 0.5072
# Epoch 20/100
# 144/144 [==============================] - 2s 17ms/step - loss: 38.4175 - accuracy: 0.5004
# Epoch 21/100
# 144/144 [==============================] - 2s 17ms/step - loss: 32.7327 - accuracy: 0.5100
# Epoch 22/100
# 144/144 [==============================] - 2s 17ms/step - loss: 39.1984 - accuracy: 0.4961
# Epoch 23/100
# 144/144 [==============================] - 2s 17ms/step - loss: 24.3206 - accuracy: 0.5059
# Epoch 24/100
# 144/144 [==============================] - 2s 17ms/step - loss: 22.6549 - accuracy: 0.5080
# Epoch 25/100
# 144/144 [==============================] - 2s 17ms/step - loss: 48.3960 - accuracy: 0.5154
# Epoch 26/100
# 144/144 [==============================] - 2s 17ms/step - loss: 37.5032 - accuracy: 0.4978
# Epoch 27/100
# 144/144 [==============================] - 2s 17ms/step - loss: 40.6794 - accuracy: 0.5041
# Epoch 28/100
# 144/144 [==============================] - 2s 17ms/step - loss: 33.2018 - accuracy: 0.5002
# Epoch 29/100
# 144/144 [==============================] - 2s 17ms/step - loss: 33.5073 - accuracy: 0.5083
# Epoch 30/100
# 144/144 [==============================] - 2s 17ms/step - loss: 27.1257 - accuracy: 0.5130
# Epoch 31/100
# 144/144 [==============================] - 2s 17ms/step - loss: 24.4254 - accuracy: 0.5139
# Epoch 32/100
# 144/144 [==============================] - 2s 17ms/step - loss: 24.2818 - accuracy: 0.5076
# Epoch 33/100
# 144/144 [==============================] - 2s 17ms/step - loss: 19.8976 - accuracy: 0.4989
# Epoch 34/100
# 144/144 [==============================] - 2s 17ms/step - loss: 44.7805 - accuracy: 0.5050
# Epoch 35/100
# 144/144 [==============================] - 2s 17ms/step - loss: 21.7312 - accuracy: 0.5046
# Epoch 36/100
# 144/144 [==============================] - 2s 17ms/step - loss: 27.1753 - accuracy: 0.5002
# Epoch 37/100
# 144/144 [==============================] - 2s 17ms/step - loss: 53.8555 - accuracy: 0.5078
# Epoch 38/100
# 144/144 [==============================] - 2s 17ms/step - loss: 36.1871 - accuracy: 0.5167
# Epoch 39/100
# 144/144 [==============================] - 2s 17ms/step - loss: 38.2453 - accuracy: 0.5080
# Epoch 40/100
# 144/144 [==============================] - 2s 17ms/step - loss: 27.9410 - accuracy: 0.5159
# Epoch 41/100
# 144/144 [==============================] - 2s 17ms/step - loss: 23.2389 - accuracy: 0.5026
# Epoch 42/100
# 144/144 [==============================] - 2s 17ms/step - loss: 15.8818 - accuracy: 0.5276
# Epoch 43/100
# 144/144 [==============================] - 2s 17ms/step - loss: 29.4209 - accuracy: 0.5093
# Epoch 44/100
# 144/144 [==============================] - 2s 17ms/step - loss: 22.5241 - accuracy: 0.5076
# Epoch 45/100
# 144/144 [==============================] - 2s 17ms/step - loss: 19.6100 - accuracy: 0.5100
# Epoch 46/100
# 144/144 [==============================] - 2s 17ms/step - loss: 24.0912 - accuracy: 0.5078
# Epoch 47/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.9685 - accuracy: 0.5163
# Epoch 48/100
# 144/144 [==============================] - 2s 17ms/step - loss: 18.0049 - accuracy: 0.4998
# Epoch 49/100
# 144/144 [==============================] - 2s 17ms/step - loss: 15.2915 - accuracy: 0.5113
# Epoch 50/100
# 144/144 [==============================] - 2s 17ms/step - loss: 11.6808 - accuracy: 0.5128
# Epoch 51/100
# 144/144 [==============================] - 2s 17ms/step - loss: 22.2454 - accuracy: 0.5098
# Epoch 52/100
# 144/144 [==============================] - 2s 17ms/step - loss: 39.8805 - accuracy: 0.5089
# Epoch 53/100
# 144/144 [==============================] - 2s 17ms/step - loss: 26.2071 - accuracy: 0.5030
# Epoch 54/100
# 144/144 [==============================] - 2s 17ms/step - loss: 18.0651 - accuracy: 0.5146
# Epoch 55/100
# 144/144 [==============================] - 2s 17ms/step - loss: 22.6851 - accuracy: 0.5089
# Epoch 56/100
# 144/144 [==============================] - 2s 17ms/step - loss: 14.4339 - accuracy: 0.4991
# Epoch 57/100
# 144/144 [==============================] - 2s 17ms/step - loss: 21.2884 - accuracy: 0.5117
# Epoch 58/100
# 144/144 [==============================] - 2s 17ms/step - loss: 16.9476 - accuracy: 0.5102
# Epoch 59/100
# 144/144 [==============================] - 2s 17ms/step - loss: 11.1681 - accuracy: 0.5096
# Epoch 60/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.3524 - accuracy: 0.5128
# Epoch 61/100
# 144/144 [==============================] - 2s 17ms/step - loss: 20.8893 - accuracy: 0.4944
# Epoch 62/100
# 144/144 [==============================] - 2s 17ms/step - loss: 21.8020 - accuracy: 0.5187
# Epoch 63/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.8816 - accuracy: 0.4948
# Epoch 64/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.7641 - accuracy: 0.5087
# Epoch 65/100
# 144/144 [==============================] - 2s 17ms/step - loss: 15.0375 - accuracy: 0.5122
# Epoch 66/100
# 144/144 [==============================] - 2s 17ms/step - loss: 12.5791 - accuracy: 0.5087
# Epoch 67/100
# 144/144 [==============================] - 2s 17ms/step - loss: 22.9204 - accuracy: 0.5022
# Epoch 68/100
# 144/144 [==============================] - 2s 17ms/step - loss: 17.7030 - accuracy: 0.5026
# Epoch 69/100
# 144/144 [==============================] - 2s 17ms/step - loss: 11.8829 - accuracy: 0.5065
# Epoch 70/100
# 144/144 [==============================] - 2s 17ms/step - loss: 16.5988 - accuracy: 0.5261
# Epoch 71/100
# 144/144 [==============================] - 2s 17ms/step - loss: 12.5322 - accuracy: 0.5230
# Epoch 72/100
# 144/144 [==============================] - 2s 17ms/step - loss: 22.7706 - accuracy: 0.4993
# Epoch 73/100
# 144/144 [==============================] - 2s 17ms/step - loss: 18.2316 - accuracy: 0.5007
# Epoch 74/100
# 144/144 [==============================] - 2s 17ms/step - loss: 22.3091 - accuracy: 0.5085
# Epoch 75/100
# 144/144 [==============================] - 2s 17ms/step - loss: 12.2588 - accuracy: 0.5161
# Epoch 76/100
# 144/144 [==============================] - 2s 17ms/step - loss: 9.4990 - accuracy: 0.4954
# Epoch 77/100
# 144/144 [==============================] - 2s 17ms/step - loss: 19.0593 - accuracy: 0.5037
# Epoch 78/100
# 144/144 [==============================] - 2s 17ms/step - loss: 18.1032 - accuracy: 0.5007
# Epoch 79/100
# 144/144 [==============================] - 2s 17ms/step - loss: 12.0406 - accuracy: 0.5154
# Epoch 80/100
# 144/144 [==============================] - 2s 17ms/step - loss: 12.1142 - accuracy: 0.5126
# Epoch 81/100
# 144/144 [==============================] - 2s 17ms/step - loss: 17.2612 - accuracy: 0.5098
# Epoch 82/100
# 144/144 [==============================] - 2s 17ms/step - loss: 17.9072 - accuracy: 0.4965
# Epoch 83/100
# 144/144 [==============================] - 2s 17ms/step - loss: 14.2065 - accuracy: 0.5028
# Epoch 84/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.9852 - accuracy: 0.5172
# Epoch 85/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.7628 - accuracy: 0.5022
# Epoch 86/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.0189 - accuracy: 0.5080
# Epoch 87/100
# 144/144 [==============================] - 2s 17ms/step - loss: 12.0990 - accuracy: 0.5063
# Epoch 88/100
# 144/144 [==============================] - 2s 17ms/step - loss: 11.9765 - accuracy: 0.5063
# Epoch 89/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.7458 - accuracy: 0.5115
# Epoch 90/100
# 144/144 [==============================] - 2s 17ms/step - loss: 8.7172 - accuracy: 0.5041
# Epoch 91/100
# 144/144 [==============================] - 2s 17ms/step - loss: 17.6808 - accuracy: 0.5056
# Epoch 92/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.0166 - accuracy: 0.4852
# Epoch 93/100
# 144/144 [==============================] - 2s 17ms/step - loss: 8.2242 - accuracy: 0.4983
# Epoch 94/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.0847 - accuracy: 0.4946
# Epoch 95/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.5165 - accuracy: 0.5059
# Epoch 96/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.4471 - accuracy: 0.5065
# Epoch 97/100
# 144/144 [==============================] - 2s 17ms/step - loss: 12.2788 - accuracy: 0.4913
# Epoch 98/100
# 144/144 [==============================] - 2s 17ms/step - loss: 8.0899 - accuracy: 0.5043
# Epoch 99/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.0364 - accuracy: 0.4985
# Epoch 100/100
# 144/144 [==============================] - 2s 17ms/step - loss: 8.4095 - accuracy: 0.5098
# 36/36 [==============================] - 1s 20ms/step
# Train model_15...
# Epoch 1/100
# 144/144 [==============================] - 5s 18ms/step - loss: 953.5910 - accuracy: 0.5107
# Epoch 2/100
# 144/144 [==============================] - 2s 17ms/step - loss: 191.1106 - accuracy: 0.5176
# Epoch 3/100
# 144/144 [==============================] - 2s 17ms/step - loss: 233.3424 - accuracy: 0.5141
# Epoch 4/100
# 144/144 [==============================] - 2s 17ms/step - loss: 97.6713 - accuracy: 0.5118
# Epoch 5/100
# 144/144 [==============================] - 2s 17ms/step - loss: 65.4105 - accuracy: 0.5152
# Epoch 6/100
# 144/144 [==============================] - 2s 17ms/step - loss: 121.3015 - accuracy: 0.5111
# Epoch 7/100
# 144/144 [==============================] - 2s 17ms/step - loss: 72.0864 - accuracy: 0.5067
# Epoch 8/100
# 144/144 [==============================] - 2s 17ms/step - loss: 38.5686 - accuracy: 0.5246
# Epoch 9/100
# 144/144 [==============================] - 2s 17ms/step - loss: 45.5285 - accuracy: 0.5096
# Epoch 10/100
# 144/144 [==============================] - 2s 17ms/step - loss: 50.6433 - accuracy: 0.5037
# Epoch 11/100
# 144/144 [==============================] - 2s 17ms/step - loss: 58.7172 - accuracy: 0.5152
# Epoch 12/100
# 144/144 [==============================] - 2s 17ms/step - loss: 51.0277 - accuracy: 0.5094
# Epoch 13/100
# 144/144 [==============================] - 2s 17ms/step - loss: 74.6958 - accuracy: 0.4889
# Epoch 14/100
# 144/144 [==============================] - 2s 17ms/step - loss: 70.1923 - accuracy: 0.4976
# Epoch 15/100
# 144/144 [==============================] - 2s 17ms/step - loss: 57.3214 - accuracy: 0.5226
# Epoch 16/100
# 144/144 [==============================] - 2s 17ms/step - loss: 37.7656 - accuracy: 0.5148
# Epoch 17/100
# 144/144 [==============================] - 2s 17ms/step - loss: 45.2471 - accuracy: 0.5257
# Epoch 18/100
# 144/144 [==============================] - 2s 17ms/step - loss: 30.8356 - accuracy: 0.5044
# Epoch 19/100
# 144/144 [==============================] - 2s 17ms/step - loss: 30.1690 - accuracy: 0.5050
# Epoch 20/100
# 144/144 [==============================] - 2s 17ms/step - loss: 29.4990 - accuracy: 0.5089
# Epoch 21/100
# 144/144 [==============================] - 2s 17ms/step - loss: 46.3890 - accuracy: 0.5144
# Epoch 22/100
# 144/144 [==============================] - 2s 17ms/step - loss: 35.1853 - accuracy: 0.5024
# Epoch 23/100
# 144/144 [==============================] - 2s 17ms/step - loss: 37.5653 - accuracy: 0.5009
# Epoch 24/100
# 144/144 [==============================] - 2s 17ms/step - loss: 23.3925 - accuracy: 0.5205
# Epoch 25/100
# 144/144 [==============================] - 2s 17ms/step - loss: 32.1990 - accuracy: 0.5085
# Epoch 26/100
# 144/144 [==============================] - 2s 17ms/step - loss: 35.9270 - accuracy: 0.4956
# Epoch 27/100
# 144/144 [==============================] - 2s 17ms/step - loss: 31.2350 - accuracy: 0.5255
# Epoch 28/100
# 144/144 [==============================] - 2s 17ms/step - loss: 29.3824 - accuracy: 0.5157
# Epoch 29/100
# 144/144 [==============================] - 2s 17ms/step - loss: 27.3396 - accuracy: 0.5126
# Epoch 30/100
# 144/144 [==============================] - 2s 17ms/step - loss: 32.6567 - accuracy: 0.5111
# Epoch 31/100
# 144/144 [==============================] - 2s 17ms/step - loss: 16.9223 - accuracy: 0.5159
# Epoch 32/100
# 144/144 [==============================] - 2s 17ms/step - loss: 17.7061 - accuracy: 0.5041
# Epoch 33/100
# 144/144 [==============================] - 2s 17ms/step - loss: 22.4379 - accuracy: 0.5202
# Epoch 34/100
# 144/144 [==============================] - 2s 17ms/step - loss: 17.8108 - accuracy: 0.5168
# Epoch 35/100
# 144/144 [==============================] - 2s 17ms/step - loss: 26.5548 - accuracy: 0.5050
# Epoch 36/100
# 144/144 [==============================] - 2s 17ms/step - loss: 27.2659 - accuracy: 0.5194
# Epoch 37/100
# 144/144 [==============================] - 2s 17ms/step - loss: 28.7759 - accuracy: 0.5028
# Epoch 38/100
# 144/144 [==============================] - 2s 17ms/step - loss: 21.1595 - accuracy: 0.5057
# Epoch 39/100
# 144/144 [==============================] - 2s 17ms/step - loss: 22.8817 - accuracy: 0.5137
# Epoch 40/100
# 144/144 [==============================] - 2s 17ms/step - loss: 15.3306 - accuracy: 0.5102
# Epoch 41/100
# 144/144 [==============================] - 2s 17ms/step - loss: 12.7609 - accuracy: 0.5239
# Epoch 42/100
# 144/144 [==============================] - 2s 17ms/step - loss: 15.8354 - accuracy: 0.5059
# Epoch 43/100
# 144/144 [==============================] - 2s 17ms/step - loss: 19.8316 - accuracy: 0.5172
# Epoch 44/100
# 144/144 [==============================] - 2s 17ms/step - loss: 21.5221 - accuracy: 0.5054
# Epoch 45/100
# 144/144 [==============================] - 2s 17ms/step - loss: 12.3317 - accuracy: 0.5139
# Epoch 46/100
# 144/144 [==============================] - 2s 17ms/step - loss: 7.5075 - accuracy: 0.5194
# Epoch 47/100
# 144/144 [==============================] - 2s 17ms/step - loss: 9.3758 - accuracy: 0.4974
# Epoch 48/100
# 144/144 [==============================] - 2s 16ms/step - loss: 8.8194 - accuracy: 0.5187
# Epoch 49/100
# 144/144 [==============================] - 2s 17ms/step - loss: 18.5309 - accuracy: 0.5152
# Epoch 50/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.7398 - accuracy: 0.5196
# Epoch 51/100
# 144/144 [==============================] - 2s 17ms/step - loss: 11.4916 - accuracy: 0.5085
# Epoch 52/100
# 144/144 [==============================] - 2s 17ms/step - loss: 11.3628 - accuracy: 0.5229
# Epoch 53/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.2879 - accuracy: 0.5063
# Epoch 54/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.9202 - accuracy: 0.4839
# Epoch 55/100
# 144/144 [==============================] - 2s 17ms/step - loss: 7.4751 - accuracy: 0.5174
# Epoch 56/100
# 144/144 [==============================] - 2s 17ms/step - loss: 12.2745 - accuracy: 0.5135
# Epoch 57/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.7700 - accuracy: 0.5085
# Epoch 58/100
# 144/144 [==============================] - 2s 17ms/step - loss: 8.3201 - accuracy: 0.4974
# Epoch 59/100
# 144/144 [==============================] - 2s 17ms/step - loss: 11.5045 - accuracy: 0.5061
# Epoch 60/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.9421 - accuracy: 0.5111
# Epoch 61/100
# 144/144 [==============================] - 2s 17ms/step - loss: 6.7890 - accuracy: 0.5279
# Epoch 62/100
# 144/144 [==============================] - 2s 17ms/step - loss: 6.2606 - accuracy: 0.5102
# Epoch 63/100
# 144/144 [==============================] - 2s 17ms/step - loss: 7.3463 - accuracy: 0.5172
# Epoch 64/100
# 144/144 [==============================] - 2s 17ms/step - loss: 11.5132 - accuracy: 0.5235
# Epoch 65/100
# 144/144 [==============================] - 2s 17ms/step - loss: 8.7064 - accuracy: 0.5109
# Epoch 66/100
# 144/144 [==============================] - 2s 17ms/step - loss: 11.0814 - accuracy: 0.5054
# Epoch 67/100
# 144/144 [==============================] - 2s 17ms/step - loss: 6.6014 - accuracy: 0.5033
# Epoch 68/100
# 144/144 [==============================] - 2s 17ms/step - loss: 6.3938 - accuracy: 0.5246
# Epoch 69/100
# 144/144 [==============================] - 3s 18ms/step - loss: 7.5751 - accuracy: 0.5198
# Epoch 70/100
# 144/144 [==============================] - 2s 17ms/step - loss: 5.5856 - accuracy: 0.5115
# Epoch 71/100
# 144/144 [==============================] - 2s 17ms/step - loss: 9.8430 - accuracy: 0.5013
# Epoch 72/100
# 144/144 [==============================] - 2s 17ms/step - loss: 8.3101 - accuracy: 0.5176
# Epoch 73/100
# 144/144 [==============================] - 2s 17ms/step - loss: 9.6580 - accuracy: 0.5170
# Epoch 74/100
# 144/144 [==============================] - 2s 17ms/step - loss: 9.5577 - accuracy: 0.5072
# Epoch 75/100
# 144/144 [==============================] - 2s 17ms/step - loss: 8.4003 - accuracy: 0.5087
# Epoch 76/100
# 144/144 [==============================] - 2s 17ms/step - loss: 8.1017 - accuracy: 0.5235
# Epoch 77/100
# 144/144 [==============================] - 2s 17ms/step - loss: 5.9049 - accuracy: 0.5198
# Epoch 78/100
# 144/144 [==============================] - 2s 17ms/step - loss: 9.0272 - accuracy: 0.5020
# Epoch 79/100
# 144/144 [==============================] - 2s 17ms/step - loss: 8.8291 - accuracy: 0.5172
# Epoch 80/100
# 144/144 [==============================] - 2s 17ms/step - loss: 8.5877 - accuracy: 0.4950
# Epoch 81/100
# 144/144 [==============================] - 2s 17ms/step - loss: 8.3273 - accuracy: 0.5196
# Epoch 82/100
# 144/144 [==============================] - 2s 17ms/step - loss: 4.4404 - accuracy: 0.5176
# Epoch 83/100
# 144/144 [==============================] - 2s 17ms/step - loss: 6.4592 - accuracy: 0.5205
# Epoch 84/100
# 144/144 [==============================] - 2s 17ms/step - loss: 5.4133 - accuracy: 0.4915
# Epoch 85/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.6862 - accuracy: 0.5059
# Epoch 86/100
# 144/144 [==============================] - 2s 17ms/step - loss: 7.6474 - accuracy: 0.5207
# Epoch 87/100
# 144/144 [==============================] - 2s 17ms/step - loss: 7.7535 - accuracy: 0.5287
# Epoch 88/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.5346 - accuracy: 0.5057
# Epoch 89/100
# 144/144 [==============================] - 2s 17ms/step - loss: 8.7255 - accuracy: 0.5063
# Epoch 90/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.9199 - accuracy: 0.5048
# Epoch 91/100
# 144/144 [==============================] - 2s 17ms/step - loss: 9.1976 - accuracy: 0.5094
# Epoch 92/100
# 144/144 [==============================] - 2s 17ms/step - loss: 5.2334 - accuracy: 0.5087
# Epoch 93/100
# 144/144 [==============================] - 2s 17ms/step - loss: 9.8016 - accuracy: 0.5181
# Epoch 94/100
# 144/144 [==============================] - 2s 17ms/step - loss: 7.3134 - accuracy: 0.5041
# Epoch 95/100
# 144/144 [==============================] - 2s 17ms/step - loss: 8.9393 - accuracy: 0.5048
# Epoch 96/100
# 144/144 [==============================] - 2s 17ms/step - loss: 8.1366 - accuracy: 0.5061
# Epoch 97/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.1933 - accuracy: 0.5137
# Epoch 98/100
# 144/144 [==============================] - 3s 17ms/step - loss: 6.7200 - accuracy: 0.5218
# Epoch 99/100
# 144/144 [==============================] - 3s 17ms/step - loss: 7.3949 - accuracy: 0.5028
# Epoch 100/100
# 144/144 [==============================] - 2s 17ms/step - loss: 7.4771 - accuracy: 0.5030
# 36/36 [==============================] - 1s 21ms/step
# Train model_30...
# Epoch 1/100
# 144/144 [==============================] - 5s 18ms/step - loss: 1058.6487 - accuracy: 0.5110
# Epoch 2/100
# 144/144 [==============================] - 2s 17ms/step - loss: 406.7343 - accuracy: 0.5185
# Epoch 3/100
# 144/144 [==============================] - 2s 17ms/step - loss: 286.7926 - accuracy: 0.5150
# Epoch 4/100
# 144/144 [==============================] - 2s 17ms/step - loss: 147.6847 - accuracy: 0.4942
# Epoch 5/100
# 144/144 [==============================] - 2s 17ms/step - loss: 116.6208 - accuracy: 0.5071
# Epoch 6/100
# 144/144 [==============================] - 2s 17ms/step - loss: 99.4734 - accuracy: 0.5211
# Epoch 7/100
# 144/144 [==============================] - 2s 17ms/step - loss: 128.4876 - accuracy: 0.5145
# Epoch 8/100
# 144/144 [==============================] - 2s 17ms/step - loss: 82.3212 - accuracy: 0.5117
# Epoch 9/100
# 144/144 [==============================] - 2s 17ms/step - loss: 93.5217 - accuracy: 0.5119
# Epoch 10/100
# 144/144 [==============================] - 2s 17ms/step - loss: 64.1875 - accuracy: 0.5287
# Epoch 11/100
# 144/144 [==============================] - 2s 17ms/step - loss: 70.8050 - accuracy: 0.5130
# Epoch 12/100
# 144/144 [==============================] - 2s 17ms/step - loss: 60.1664 - accuracy: 0.5060
# Epoch 13/100
# 144/144 [==============================] - 2s 17ms/step - loss: 67.4146 - accuracy: 0.5016
# Epoch 14/100
# 144/144 [==============================] - 2s 17ms/step - loss: 62.6942 - accuracy: 0.5027
# Epoch 15/100
# 144/144 [==============================] - 2s 17ms/step - loss: 35.6179 - accuracy: 0.5185
# Epoch 16/100
# 144/144 [==============================] - 2s 17ms/step - loss: 64.8364 - accuracy: 0.5152
# Epoch 17/100
# 144/144 [==============================] - 2s 17ms/step - loss: 52.4862 - accuracy: 0.5106
# Epoch 18/100
# 144/144 [==============================] - 2s 17ms/step - loss: 46.1806 - accuracy: 0.5230
# Epoch 19/100
# 144/144 [==============================] - 2s 17ms/step - loss: 43.8266 - accuracy: 0.5180
# Epoch 20/100
# 144/144 [==============================] - 2s 17ms/step - loss: 44.9085 - accuracy: 0.5246
# Epoch 21/100
# 144/144 [==============================] - 2s 17ms/step - loss: 55.9164 - accuracy: 0.5285
# Epoch 22/100
# 144/144 [==============================] - 2s 17ms/step - loss: 51.4504 - accuracy: 0.5117
# Epoch 23/100
# 144/144 [==============================] - 2s 17ms/step - loss: 46.0819 - accuracy: 0.4986
# Epoch 24/100
# 144/144 [==============================] - 2s 17ms/step - loss: 33.4763 - accuracy: 0.5257
# Epoch 25/100
# 144/144 [==============================] - 2s 17ms/step - loss: 33.9865 - accuracy: 0.5139
# Epoch 26/100
# 144/144 [==============================] - 2s 17ms/step - loss: 67.7192 - accuracy: 0.5169
# Epoch 27/100
# 144/144 [==============================] - 2s 17ms/step - loss: 47.3593 - accuracy: 0.5217
# Epoch 28/100
# 144/144 [==============================] - 2s 17ms/step - loss: 31.7445 - accuracy: 0.5287
# Epoch 29/100
# 144/144 [==============================] - 2s 17ms/step - loss: 26.5370 - accuracy: 0.5285
# Epoch 30/100
# 144/144 [==============================] - 2s 17ms/step - loss: 28.6615 - accuracy: 0.5150
# Epoch 31/100
# 144/144 [==============================] - 2s 17ms/step - loss: 20.6952 - accuracy: 0.5189
# Epoch 32/100
# 144/144 [==============================] - 2s 17ms/step - loss: 19.9827 - accuracy: 0.5189
# Epoch 33/100
# 144/144 [==============================] - 2s 17ms/step - loss: 20.2594 - accuracy: 0.5263
# Epoch 34/100
# 144/144 [==============================] - 2s 17ms/step - loss: 28.4081 - accuracy: 0.5150
# Epoch 35/100
# 144/144 [==============================] - 2s 17ms/step - loss: 20.0559 - accuracy: 0.5248
# Epoch 36/100
# 144/144 [==============================] - 2s 17ms/step - loss: 16.6484 - accuracy: 0.5285
# Epoch 37/100
# 144/144 [==============================] - 2s 17ms/step - loss: 16.2254 - accuracy: 0.5385
# Epoch 38/100
# 144/144 [==============================] - 2s 17ms/step - loss: 25.3713 - accuracy: 0.5206
# Epoch 39/100
# 144/144 [==============================] - 2s 17ms/step - loss: 23.6315 - accuracy: 0.5230
# Epoch 40/100
# 144/144 [==============================] - 2s 17ms/step - loss: 19.3747 - accuracy: 0.5274
# Epoch 41/100
# 144/144 [==============================] - 2s 17ms/step - loss: 14.2674 - accuracy: 0.5093
# Epoch 42/100
# 144/144 [==============================] - 2s 17ms/step - loss: 19.1162 - accuracy: 0.5032
# Epoch 43/100
# 144/144 [==============================] - 2s 17ms/step - loss: 32.3797 - accuracy: 0.5091
# Epoch 44/100
# 144/144 [==============================] - 2s 17ms/step - loss: 33.7681 - accuracy: 0.5156
# Epoch 45/100
# 144/144 [==============================] - 2s 17ms/step - loss: 12.6456 - accuracy: 0.5287
# Epoch 46/100
# 144/144 [==============================] - 2s 17ms/step - loss: 11.9852 - accuracy: 0.5143
# Epoch 47/100
# 144/144 [==============================] - 2s 17ms/step - loss: 16.6245 - accuracy: 0.5091
# Epoch 48/100
# 144/144 [==============================] - 2s 17ms/step - loss: 19.0148 - accuracy: 0.5143
# Epoch 49/100
# 144/144 [==============================] - 2s 17ms/step - loss: 14.5985 - accuracy: 0.5176
# Epoch 50/100
# 144/144 [==============================] - 2s 17ms/step - loss: 22.0124 - accuracy: 0.5152
# Epoch 51/100
# 144/144 [==============================] - 2s 17ms/step - loss: 16.5194 - accuracy: 0.5185
# Epoch 52/100
# 144/144 [==============================] - 2s 17ms/step - loss: 24.3528 - accuracy: 0.5230
# Epoch 53/100
# 144/144 [==============================] - 2s 17ms/step - loss: 15.8150 - accuracy: 0.5195
# Epoch 54/100
# 144/144 [==============================] - 2s 17ms/step - loss: 12.2278 - accuracy: 0.5054
# Epoch 55/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.6674 - accuracy: 0.5248
# Epoch 56/100
# 144/144 [==============================] - 2s 17ms/step - loss: 12.8231 - accuracy: 0.5106
# Epoch 57/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.2961 - accuracy: 0.5176
# Epoch 58/100
# 144/144 [==============================] - 2s 17ms/step - loss: 15.0453 - accuracy: 0.5176
# Epoch 59/100
# 144/144 [==============================] - 2s 17ms/step - loss: 21.2360 - accuracy: 0.5132
# Epoch 60/100
# 144/144 [==============================] - 2s 17ms/step - loss: 17.9560 - accuracy: 0.5163
# Epoch 61/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.4293 - accuracy: 0.5115
# Epoch 62/100
# 144/144 [==============================] - 2s 17ms/step - loss: 47.9533 - accuracy: 0.5152
# Epoch 63/100
# 144/144 [==============================] - 2s 17ms/step - loss: 26.1886 - accuracy: 0.5093
# Epoch 64/100
# 144/144 [==============================] - 2s 17ms/step - loss: 20.5795 - accuracy: 0.5278
# Epoch 65/100
# 144/144 [==============================] - 2s 17ms/step - loss: 15.0663 - accuracy: 0.5161
# Epoch 66/100
# 144/144 [==============================] - 2s 17ms/step - loss: 12.7305 - accuracy: 0.5217
# Epoch 67/100
# 144/144 [==============================] - 2s 17ms/step - loss: 9.0630 - accuracy: 0.5130
# Epoch 68/100
# 144/144 [==============================] - 2s 17ms/step - loss: 21.2760 - accuracy: 0.5147
# Epoch 69/100
# 144/144 [==============================] - 2s 17ms/step - loss: 9.4316 - accuracy: 0.5302
# Epoch 70/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.2713 - accuracy: 0.5206
# Epoch 71/100
# 144/144 [==============================] - 2s 16ms/step - loss: 15.9389 - accuracy: 0.5161
# Epoch 72/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.0275 - accuracy: 0.5158
# Epoch 73/100
# 144/144 [==============================] - 2s 17ms/step - loss: 12.7951 - accuracy: 0.5228
# Epoch 74/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.8145 - accuracy: 0.5259
# Epoch 75/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.6823 - accuracy: 0.5147
# Epoch 76/100
# 144/144 [==============================] - 2s 17ms/step - loss: 13.9158 - accuracy: 0.5191
# Epoch 77/100
# 144/144 [==============================] - 2s 17ms/step - loss: 9.2625 - accuracy: 0.5254
# Epoch 78/100
# 144/144 [==============================] - 2s 17ms/step - loss: 8.8874 - accuracy: 0.5180
# Epoch 79/100
# 144/144 [==============================] - 2s 17ms/step - loss: 7.6492 - accuracy: 0.5268
# Epoch 80/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.4173 - accuracy: 0.5119
# Epoch 81/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.6173 - accuracy: 0.5237
# Epoch 82/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.3738 - accuracy: 0.5189
# Epoch 83/100
# 144/144 [==============================] - 2s 17ms/step - loss: 18.0640 - accuracy: 0.5276
# Epoch 84/100
# 144/144 [==============================] - 2s 17ms/step - loss: 9.0530 - accuracy: 0.5075
# Epoch 85/100
# 144/144 [==============================] - 2s 17ms/step - loss: 9.1778 - accuracy: 0.5167
# Epoch 86/100
# 144/144 [==============================] - 2s 17ms/step - loss: 8.1426 - accuracy: 0.5342
# Epoch 87/100
# 144/144 [==============================] - 2s 17ms/step - loss: 10.2304 - accuracy: 0.5200
# Epoch 88/100
# 144/144 [==============================] - 2s 16ms/step - loss: 9.5977 - accuracy: 0.5285
# Epoch 89/100
# 144/144 [==============================] - 2s 16ms/step - loss: 8.5518 - accuracy: 0.5141
# Epoch 90/100
# 144/144 [==============================] - 2s 16ms/step - loss: 7.5538 - accuracy: 0.5152
# Epoch 91/100
# 144/144 [==============================] - 2s 16ms/step - loss: 15.0294 - accuracy: 0.5202
# Epoch 92/100
# 144/144 [==============================] - 2s 16ms/step - loss: 12.9015 - accuracy: 0.5130
# Epoch 93/100
# 144/144 [==============================] - 2s 16ms/step - loss: 11.3753 - accuracy: 0.5051
# Epoch 94/100
# 144/144 [==============================] - 2s 16ms/step - loss: 9.4979 - accuracy: 0.5178
# Epoch 95/100
# 144/144 [==============================] - 2s 16ms/step - loss: 10.2781 - accuracy: 0.5080
# Epoch 96/100
# 144/144 [==============================] - 2s 16ms/step - loss: 12.3818 - accuracy: 0.5219
# Epoch 97/100
# 144/144 [==============================] - 2s 16ms/step - loss: 10.5338 - accuracy: 0.5126
# Epoch 98/100
# 144/144 [==============================] - 2s 16ms/step - loss: 8.2527 - accuracy: 0.5178
# Epoch 99/100
# 144/144 [==============================] - 2s 16ms/step - loss: 7.8729 - accuracy: 0.5115
# Epoch 100/100
# 144/144 [==============================] - 2s 16ms/step - loss: 7.6879 - accuracy: 0.5141
# 36/36 [==============================] - 1s 20ms/step

# %%
model_1.save('/home/work/nlp/TCN_models/classification_model/v5/kospi_1day_classification_v5.h5')
model_7.save('/home/work/nlp/TCN_models/classification_model/v5/kospi_7days_classification_v5.h5')
model_15.save('/home/work/nlp/TCN_models/classification_model/v5/kospi_15days_classification_v5.h5')
model_30.save('/home/work/nlp/TCN_models/classification_model/v5/kospi_30days_classification_v5.h5')

# %%
model_1.evaluate(x_test_1, y_test_1_e)[1]
model_7.evaluate(x_test_7, y_test_7_e)[1]
model_15.evaluate(x_test_15, y_test_15_e)[1]
model_30.evaluate(x_test_30, y_test_30_e)[1]
# Out:
# 37/37 [==============================] - 1s 20ms/step - loss: 6.2695 - accuracy: 0.4520
# 36/36 [==============================] - 1s 20ms/step - loss: 12.8526 - accuracy: 0.5191
# 36/36 [==============================] - 1s 20ms/step - loss: 3.6740 - accuracy: 0.4948
# 36/36 [==============================] - 1s 20ms/step - loss: 9.9685 - accuracy: 0.4925
# 0.49247121810913086
